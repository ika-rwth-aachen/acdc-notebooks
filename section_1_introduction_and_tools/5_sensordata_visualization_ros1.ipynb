# %% [markdown]
# ![](../assets/header_image.png)

# %% [markdown]
# # Optional Assignment 5: Introduction to 3D visualizations with ROS
#
#
# Welcome to the next optional assignment using Jupyros! This exercise notebook is optional. That means we only recommend this notebook to students who do *not* have expierenced with
#
# - **Robot Operating System (ROS)**
# - **RVIZ** / **Jupyter-Zethus**

# %% [markdown]
# In this assignment, you will learn
#
# - **how Zethus allows us to visualize the ROS messages and act as an alternative to RVIZ**
# - **how to launch the websocket to use Ros-bridge and build the connection between the ROS and the Zethus**

# %% [markdown]
# # Set up the ROS environment
#
# This command is used to set up the environment for the ROS (Robot Operating System) Noetic distribution. It sets up various environment variables, such as `ROS_PACKAGE_PATH`, that are necessary for using ROS commands and accessing the packages and libraries included with the Noetic distribution.
#
# By sourcing this file, the user can use the ROS commands and work with the Noetic distribution without having to manually set the environment variables each time.

# %%
# !source /opt/ros/noetic/setup.sh

# %%
import sys
sys.path.append('/opt/ros/noetic/lib/python3/dist-packages/')

# %% [markdown]
# # Launch three terminals from the launcher
#
# Launch three different terminals. In order to do that click on
#
# **File >> New Launcher >> Terminal**
#
# and execute the following commands in the terminals:
#
# ## 1st Terminal
#
# Open the first terminal tab in the browser and run the following code,
#
# it will setup the ros environment and launch the master node for the ROS
#
# ```bash
# source /opt/ros/noetic/setup.sh && roscore
# ```
#
# ## 2nd Terminal
#
# Open the second terminal tab in the browser and run the following code,
#
#
#
# ```bash
# source /opt/ros/noetic/setup.sh
# ```
#
# ```bash
# cd acdc/section_1_introduction_and_tools
# ```
#
# ```bash
# roslaunch websocket.launch
# ```
#
# This commands will
# - Setup the ROS environment
# - Navigate to `/acdc/section_1_introduction_and_tools`
# - Launch the launchfile `websocket.launch` to esatblish the connection between ROS and Zethus
#
#
# ## 3rd Terminal
#
# Open the third terminal tab in the browser and run the following code,
#
#
# - Setup the ros environment
# - Navigate to the /acdc/section_1_introduction_and_tools
# - Play the Rosbag `carla.bag` in the loop and start publishing the data as if data is being published from the sensors on the actual vehicle.
#
# ```bash
# source /opt/ros/noetic/setup.sh
# ```
#
# ```bash
# cd acdc/section_1_introduction_and_tools
# ```
#
# ```bash
# rosbag play -l carla_sensor_data.bag
# ```

# %% [markdown]
# # Visualize the data inside the Zethus Tool
#
# Now, it is time to launch the zethus from the launcher tab. For that follow the steps as following,
#
# ## 1. Click on - **File >> New Launcher >> Zethus**
#
# ![image.png](attachment:416cc5cd-1be3-4eaa-977d-f55fc8443c49.png)
#
# ## 2. Click on the Add visualizations
#
# ![image.png](attachment:b705720c-8972-4586-a122-e1574f22bc9d.png)
#
# - Select the topic you want to subscribe to
# - Click on proceed, type the topic name
# - Click Add visualization it would start visualizing the data inside zethus
#
# ![image.png](attachment:0fd671d7-4380-497e-ad70-cd1d1b351c95.png)
#
# ## 4. Final you should see following type of the visualization
#
# ![image.png](attachment:57f041e2-98e5-48e6-ae32-26cac55a8fea.png)

# %% [markdown]
# # Stop the Rosbag
#
# Now you should go back to the Terminal where rosbag had been lauched and stop it by clicking ctrl + C

# %% [markdown]
# # Stop the Rosbridge through websocket
#
# Now you should go back to the Terminal where websocket had been lauched and stop it by clicking ctrl+ C

# %% [markdown]
# # Stop the master
#
# - Now you should go back to the Terminal and stop the master node by clicking ctrl+ C
#
# ![image.png](attachment:9236a9cb-7e4f-43e5-a943-cd43edbeb708.png)

# %% [markdown]
# # Wrap up
#
# - You learned how to launch the Terminals and Zethus Tool in the Jupyter environment
# - You learned about Visualizing the signals in the jupyter environment using the Zethus Tool that are   being published over some topic in the ros environment
# - You learned about establishing the connection between the ROS and Zethus using the RosBridge through websocket
# - You learned how to launch the master node from the terminal and how to stop it

# %% [markdown]
# ## License
#
# MIT License
#
# Copyright 2023 Institute for Automotive Engineering of RWTH Aachen University.
